# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisK19/Cuaderno-2022---S2/blob/main/Cuaderno_de_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana 1 - Pseudocogico

# %% [markdown]
# ## Contador de Digitos
#
# Usando Pseint crear un diagrama de flujo para representar el flujo y pseudocodigo para el algoritmo de contarDigitos.
#
# - Recibiran dos parametros
# - Ambos mayores a cero

# %% [markdown]
# ###Diagrama de Flujo
# ![contadorDigitos.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo contadorDigitos
# 	Leer Num
# 	Total <- 0
# 	Mientras Num>0 Hacer
# 		Num <- trunc(Num/10)
# 		Total <- Total+1
# 	FinMientras
# 	Escribir Total
# FinAlgoritmo
# ```

# %% [markdown]
# ##CalcularIVA

# %% [markdown]
# ###Diagrama de Flujo
# ![CalcularIVA.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
# ```
# Algoritmo calcularIVA
# 	Leer precioProducto
# 	Leer Cantidad
# 	Total = precioProducto * Cantidad
# 	Total = Total * 0.13
# 	Escribir Total
# FinAlgoritmo
#
# ```

# %% [markdown]
# ##CompararNumero

# %% [markdown]
# ###Diagrama de Flujo
# ![compararNumeros.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
#
# ```
# Algoritmo compararNumeros
# 	Leer a
# 	Leer b
# 	Si a > b Entonces
# 		Escribir a
# 	SiNo
# 		Escribir b
# 	FinSi
# FinAlgoritmo
#
# ```

# %% [markdown]
# ##Operadores

# %% [markdown]
# ###Diagrama de Flujo
# ![operadores.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
# ```
# Algoritmo operadores
# 	Leer Num
# 	Potencia <- Num^2
# 	Escribir Potencia
# 	Division = trunc(Num / 10)
# 	Escribir Division
# 	Modulo = Num MOD 10
# 	Escribir Modulo
# FinAlgoritmo
# ```

# %% [markdown]
# # Semana 2 - Ejercicios

# %% [markdown]
# ##Ejercicio 1: Promedio de 4 numeros

# %% [markdown]
# ###Diagrama de flujo
# ![ejercicio1.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo Ejercicio1
# 	Leer N1
# 	Leer N2
# 	Leer N3
# 	Leer N4
# 	Total = (N1 + N2 + N3 + N4)/ 4
# 	Escribir Total
# FinAlgoritmo
#
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: Ejercicio1
# Entrada: Valor de 4 parametros
# Salida: resultado de la suma de cuatro numeros divido entre 4
# Restricciones: deber ser solo numeros enteros
# """
# def ejercicio1(Num1, Num2, Num3, Num4):
#     if isinstance(Num1, int) and isinstance(Num2, int) and isinstance(Num3, int) and isinstance(Num4, int):
#         result = (Num1 + Num2 + Num3 + Num4) / 4
#
#     return result
#
# ```

# %% [markdown]
# ##Ejercicio 2: Volumen de una caja

# %% [markdown]
# ###Diagrama de Flujo
# ![ejercicio2.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo Ejercicio2
# 	Leer Largo
# 	Leer Ancho
# 	Leer Alto
# 	Volumen = Largo*Ancho*Alto
# 	Escribir Volumen
# FinAlgoritmo
#
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: Ejercicio2
# Entrada: parametros
# Salida: suma de parametros
# Restricciones:
# """
# def ejercicio2(Num1, Num2, Num3):
#     if isinstance(Num1, int) and isinstance(Num2, int) and isinstance(Num3, int):
#         Volumen = Num1 * Num2 * Num3
#
#     return Volumen
#
# ```

# %% [markdown]
# ##Ejercicio 3: Area de la circunferencia

# %% [markdown]
# ###Diagrama de Flujo
# ![ejercicio3.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo Ejercicio3
# 	Leer r
# 	p <- 3.14
# 	area <- p*r*r
# 	Escribir area
# FinAlgoritmo
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: Ejercicio3
# Entrada: solo un parametro
# Salida: Calculo del area de la circunferencia
# Restricciones:
# """
# def ejercicio3(Num):
#     if isinstance(Num, int):
#         Pi = 3.14
#         Area = Pi * Num * Num
#
#     return Area
#
# ```

# %% [markdown]
# ##Ejercicio 6: Verificar si puede votar

# %% [markdown]
# ###Diagrama de Flujo
# ![ejercicio6.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo Ejercicio6
# 	Leer Edad
# 	Si Edad>=18 Entonces
# 		Escribir "Puede votar"
# 	SiNo
# 		Escribir "No tiene edad para votar"
# 	FinSi
# FinAlgoritmo
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: Ejercicio6
# Entrada: solo un parametro
# Salida: Calcular si la edad de la persona es mayor a 18
# Restricciones:
# """
# def ejercicio6(Num):
#     if isinstance(Num, int):
#         if Num >= 18:
#             print("votante")
#         else:
#             print("no votante")
#
# ```

# %% [markdown]
# ##Ejercicio 7: Pago de un traje

# %% [markdown]
# ###Diagrama de Flujo
# ![ejercicio7.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo Ejercicio7
# 	Leer Traje
# 	Si Traje>2500 Entonces
# 		Descuento15 <- Traje * 0.15
# 		Escribir Descuento15
# 		Total15 <- Traje - Descuento15
# 		Escribir Total15
# 	SiNo
# 		Descuento8 <- Traje * 0.08
# 		Escribir Descuento8
# 		Total8 <- Traje - Descuento8
# 		Escribir Total8
# 	FinSi
# FinAlgoritmo
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: Ejercicio7
# Entrada: solo un parametro
# Salida: Calcular el descuento del traje dependiendo en su precio y su suma total
# Restricciones:
# """
# def ejercicio7(Num):
#     if isinstance(Num, int):
#         if Num > 2500:
#             Descuento15 = Num * 0.15
#             print(Descuento15)
#             total = Num - Descuento15
#             print(total)
#
#         else:
#             Descuento8 = Num * 0.08
#             print(Descuento8)
#             total = Num - Descuento8
#             print(total)
# ```

# %% [markdown]
# ##Ejercicio 8: Presupuesto para un evento

# %% [markdown]
# ###Diagrama de Flujo
# ![ejercicio9.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo ejercicio8
# 	Leer numPersonas
# 	costo1 = 9500
# 	costo2 = 8500
# 	costo3 = 7500
# 	Si numPersonas < 5 y numPersonas >= 1 Entonces
# 		Precio = numPersonas*costo1
# 		Escribir Precio
# 	FinSi
# 	Si numPersonas <= 10 y numpersonas >= 5 Entonces
# 		Precio = numPersonas*costo2
# 		Escribir Precio
# 	FinSi
# 	Si numPersonas >= 11 Entonces
# 		Precio = numPersonas*costo3
# 		Escribir Precio
# 	FinSi
# FinAlgoritmo
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: Ejercicio8
# Entrada: solo un parametro
# Salida: Calcular el precio de los platillos por la cantidad de persona
# Restricciones: debe ser Entero y mayor a cero
# """
# def ejercicio8(Num):
#     if isinstance(Num, int):
#         if Num < 5 and Num >= 1:
#             Platillo = 9500
#             print(Num * Platillo)
#         elif Num <= 10 and Num >= 5:
#             Platillo = 8500
#             print(Num * Platillo)
#         elif Num >= 11:
#             Platillo = 7500
#             print(Num * Platillo)
#         elif Num <= 0:
#              print("Error:El número debe ser mayor a cero")
# ```

# %% [markdown]
# ##Ejercicio 9: EsPar

# %% [markdown]
# ###Diagrama de Flujo
# ![ejercicio9.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
# ```
# Algoritmo ejercicio9
# 	Leer N
# 	Si N>=0 Entonces
# 		Si N MOD 2=0 Entonces
# 			Escribir 'True'
# 		SiNo
# 			Escribir 'False'
# 		FinSi
# 	SiNo
# 		Escribir "Error: El Numero de ser Mayor o igual a 0"
# 	FinSi
# FinAlgoritmo
#
# ```

# %% [markdown]
# ###Codigo de Python
#
# ```
# """
# Nombre: Ejercicio9
# Entrada: solo un parametro
# Salida: Calcular si el numero es par o impar
# Restricciones: número debe ser entero y mayor o igual a
# cero
# """
# def ejercicio9(Num):
#     if isinstance(Num, int):
#         if (Num < 0):
#             return "Error: El numero debe ser Mayor o Igual a cero"
#         if Num % 2 == 0:
#             print("True")
#         else:
#             print("False")
#
#
# ```

# %% [markdown]
# ##Ejercicio 12-B: Contar digitos pares

# %% [markdown]
# ###Diagrama de Flujo
# ![ejercicio12b.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo ejercicio12_B
# 	Leer Num
# 	Contador <- 0
# 	Si Num>0 Entonces
# 		Mientras Num > 0 Hacer
# 			digito <- Num%10
# 			Si digito mod 2 == 0 Entonces
# 				Contador <- Contador+1
# 			FinSi
# 			Num <- trunc(Num/10)
# 		FinMientras
# 		Escribir Contador
# 	SiNo
# 		Escribir 'Error: el numero debe ser mayor a 0'
# 	FinSi
# FinAlgoritmo
#
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: ejercicio12_B
# Entrada: solo un parametro
# Salida: obtener el conteo de dígitos pares de un número
# Restricciones: Debe ser entero y no negativo
# """
# def contarDigitosPares(num):
#     if isinstance(num, int):
#         divisor = 2
#         contador = 0
#         if( num > 0):
#             while(num != 0):
#                 digito = num % 10
#                 if(digito % divisor == 0):
#                     contador = contador + 1
#                 num = num // 10
#             return contador```

# %% [markdown]
# ##Ejercicio13: Factorial

# %% [markdown]
# ###Diagrama de Flujo
# ![ejercicio13.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo ejercicio13
# 	Leer num
# 	Si num >= 0 Entonces
# 		factor <- 1
# 		Mientras num > 0 Hacer
# 			factor <- factor*num
# 			num <- num - 1
# 		FinMientras
# 		Escribir factor
# 	SiNo
# 		Escribir "error: numero debe ser mayor a 0"
# 	FinSi
# FinAlgoritmo
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: ejercicio13
# Entrada: solo un parametro
# Salida: calcular el factorial del numero
# Restricciones: número debe ser entero y mayor o igual a
# cero
# """
# def ejercicio13(num):
#     if isinstance(num, int):
#         if num >= 0:
#             factor = 1
#             while num > 0:
#                 factor = factor * num
#                 num = num - 1
#             return factor
#
# ```

# %% [markdown]
# ##Ejercicio14: Grupo de 2 digitos

# %% [markdown]
# ###Diagrama de Flujo
# ![ejercicio14.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo ejercicio14
# 	Leer num
# 	parejas <- 0
# 	Si num > 0 Entonces
# 		Mientras num > 9 Hacer
# 			parejas = parejas + 1
# 			num <- num/100
# 		FinMientras
# 		Escribir parejas
# 	SiNo
# 		Escribir "error: numero debe ser mayor a 0"
# 	FinSi
# FinAlgoritmo
#
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: ejercicio14
# Entrada: solo un parametro
# Salida: obtener la cantidad de 2 dígitos en un número
# Restricciones: número debe ser entero y mayor o igual a
# cero
# """
# def ejercicio14(num):
#     if isinstance(num, int):
#         if num > 0:
#             parejas = 0
#             while num > 9:
#                 parejas = parejas + 1
#                 num = num // 100
#             return parejas
#         else:
#             print("Error")
#
# ```

# %% [markdown]
# #Semana 3

# %% [markdown]
# ##EsPrimo

# %% [markdown]
# ###Diagrama de Flujo
# ![esprimo.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo esPrimo
# 	Leer num
# 	Si num>0 Entonces
# 		resultado = verdadero
# 		contador = 2
# 		Mientras contador<num Y resultado = Verdadero Hacer
# 			Si num MOD contador>0 Entonces
# 				contador = contador + 1
# 			SiNo
# 				resultado = FALSO
# 			FinSi
# 		FinMientras
# 		Escribir resultado
# 	SiNo
# 		Escribir 'error: el nmero debe ser mayor a 0'
# 	FinSi
# FinAlgoritmo
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: EsPrimo
# Entrada: solo un parametro
# Salida: Calcular si el numero es primo o no
# Restricciones: número debe ser entero y mayor o igual a
# cero
# """
# def esPrimo(num):
#     if isinstance(num, int):
#         if num > 0:
#             resultado = True
#             contador = 2
#             while contador < num and resultado == True:
#                 if num % contador > 0:
#                     contador = contador + 1
#                 else:
#                     resultado = False
#             print(resultado)
# ```

# %% [markdown]
# ##DivisoresNumero

# %% [markdown]
# ###Diagrama de Flujo
# ![divisoresNumero.png](data:image/png;base64,...)

# %% [markdown]
# ###Pseudocodigo
#
#
# ```
# Algoritmo divisoresNumero
# 	resultado = 0
# 	contador = 1
# 	Leer num
# 	Si num >= 0 Entonces
# 		Mientras contador <= num Hacer
# 			Si num MOD contador = 0 Entonces
# 				Escribir contador
# 			FinSi
# 			contador = contador + 1
# 		FinMientras
# 		Escribir resultado
# 	SiNo
# 		Escribir 0
# 	FinSi
# FinAlgoritmo
#
# ```

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: divisoresNumero
# Entrada: solo un parametro
# Salida: calcular todos los divisores de un numero
# Restricciones: número debe ser entero y mayor o igual a
# cero
# """
# def divisoresNumero(num):
#     if isinstance(num, int):
#        divisor = 1
#        while num >= divisor:
#         if num % divisor == 0:
#             print(divisor, end = ", ")
#         divisor = divisor + 1
# ```

# %% [markdown]
# #Semana 5

# %% [markdown]
# ##Sumatoria

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: Sumatoria
# Entrada: un inicio y un fin
# Salida: suma de todos los numeros de inicio a fin
# Restricciones: debe ser entero
# """
#
# def sumatoria(inicio,fin):
#     if isinstance(inicio, int) and isinstance(fin, int):
#     result = 0
#         if fin > inicio:
#             for numero in range (inicio,fin+1):
#                 result += numero
#             return result
#         else:
#             return "ERROR: El fin debe ser mayor a inicio"
#     else:
#         return "ERROR: Tipo de parametro incorrecto"
# ```

# %% [markdown]
# ##Factorial con for

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: Factorial
# Entrada: Un numero
# Salida: Multiplicación de todos los números que hay entre el número dado y 1
# Restricciones: debe ser entero y mayor o igual a 0
# """
# def factorialFor(num):
#     if isinstance(num, int):
#         result = 1
#         if num == 0:
#             return result
#         if num > 0:
#             for x in range (1, num + 1):
#                 result = result * x
#             return result
#         else:
#             return "ERROR: Num debe ser mayor o igual a 0"
#     else:
#         return "ERROR: Tipo de parametro incorrecto"
# ```

# %% [markdown]
# ## Multi con For

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: Multi con For
# Entrada: Una lista
# Salida: Multiplicación de todos los números que hay en la lista
# Restricciones: debe ser una lista
# """
#
# def multiFor(lista):
#     if isinstance(lista, list):
#         result = 1
#         if lista == []:
#             return "ERROR: Lista no puede estar vacia"
#         else:
#             for numero in lista:
#                 result = result * numero
#             return result
#     else:
#         return "ERROR: Tipo de parametro incorrecto"
# ```

# %% [markdown]
# ##Multi con While

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: Multi con While
# Entrada: Una lista
# Salida: Multiplicación de todos los números que hay en la lista
# Restricciones: debe ser una lista
# """
#
# def multiWhile(lista):
#     if isinstance(lista, list):
#         result = 1
#         x = 0
#         if lista == []:
#             return "ERROR: Lista no puede estar vacia"
#         if lista != []:
#             while lista != []:
#                 numero = lista[0]
#                 result = numero * result
#                 lista = lista[1:]
#             return result
#     else:
#         return "ERROR: Tipo de parametro incorrecto"
# ```

# %% [markdown]
# #Semana 7

# %% [markdown]
# ##SepararParesImpares

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: separParesImpares
# Entrada: Una lista
# Salida: Una lista con una lista de numeros pares y una lista de impares
# Restricciones: debe ser una lista
# """
# def separarParesImpares(lista):
#     if isinstance(lista, list):
#         if lista != []:
#             listaTem = []
#             listaPares = []
#             listaImpares = []
#             for numero in lista:
#                 if numero % 2 == 0:
#                     listaPares += [numero]
#                 if numero % 2 != 0:
#                     listaImpares += [numero]
#             listaTem += [listaPares]
#             listaTem += [listaImpares]
#             return listaTem
#         else:
#             return "ERROR: Lista no puede estar vacia"
#     else:
#         return "ERROR: Tipo de parametro equivocado"
# ```

# %% [markdown]
# ##EliminarElemento

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: eliminarElemento
# Entrada: Una lista y un elemento
# Salida: Eliminar la primera vez que el elemento aparece en la lista
# Restricciones: debe ser una lista, solo borrar el primer elemento y crear una nueva lista sin el elemto
# """
#
# def eliminarElemento(lista, elemento):
#     if isinstance(lista, list) and isinstance(elemento, int):
#         if lista != []:
#             listaTem = []
#             result = False
#             for x in lista:
#                 if result == False:
#                     if x != elemento:
#                         listaTem += [x]
#                     if x == elemento:
#                         result = True
#                 else:
#                     listaTem += [x]
#             return listaTem
#         else:
#             return "ERROR: Lista no puede estar vacia"
#
#     else:
#         return "ERROR: Tipo de parametro equivocado"
# ```

# %% [markdown]
# ##EliminarElementos

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: eliminarElementos
# Entrada: Una lista y un elemento
# Salida: Eliminar todas las veces que el elemento aparece en la lista
# Restricciones: debe ser una lista, solo borrar el primer elemento y crear una nueva lista sin el elemento
# """
#
# def eliminarElementos(lista, elemento):
#     if isinstance(lista, list) and isinstance(elemento, int):
#         if lista != []:
#             listaTem = []
#             for x in lista:
#                 if x != elemento:
#                     listaTem += [x]
#             return listaTem
#
#         else:
#             return"Error: Lista no puede estar vacia"
#     else:
#         return "ERROR: Tipo de parametro equivocado"
# ```

# %% [markdown]
# ##Ascendente

# %% [markdown]
# ###Codigo de Python
#
#
# ```
# """
# Nombre: ascendente
# Entrada: una lista
# Salida: retorna una lista ascendente
# Restricciones: debe ser una lista y la lista no puede estar vacia.
# """
#
# def ascendente(lista):
#     if isinstance(lista, list):
#         listaTem = []
#         largo = contarLista(lista)
#         largoTem = 0
#         cont = -1000000
#         if lista != []:
#             while largo > largoTem:
#                 for num in lista:
#                     if num == cont:
#                         listaTem += [num]
#                         largoTem += 1
#
#
#                 cont += 1
#
#             print(listaTem)
#
#         else:
#             return"ERROR: Lista no puede estar vacia"
#     else:
#         return"ERROR: Tipo de parametro equivocado"
#
#
# def contarLista(lista):
#     if isinstance(lista,list):
#         cont = 0
#         for x in lista:
#             cont += 1
#         return cont
#
#     else:
#         return "ERROR: Tipo de parametro equivocado"
# ```
